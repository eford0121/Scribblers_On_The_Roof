# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from IPython.display import Image, SVG
import matplotlib.pyplot as plt

# %%
import os
import tensorflow as tf
# Out:
# C:\Users\Erin.Ford\anaconda\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
cat_data = np.load("Data_Files\sketchrnn_cat.npz", encoding="bytes", fix_imports=True)
print(cat_data.files)
# Out:
# ['test', 'train', 'valid']

# %%
train_agg = cat_data['train']
test_agg = cat_data['test']
validation_agg = cat_data['valid']

# %%
train_agg[0][0][0]
# Out:
# -3

# %%
train_agg_x0     = [train_agg[i][j][0] for i in range(0, len(train_agg)) for j in range(0, len(train_agg[i]))]
train_agg_x1     = [train_agg[i][j][1] for i in range(0, len(train_agg)) for j in range(0, len(train_agg[i]))]
train_agg_labels = [train_agg[i][j][2] for i in range(0, len(train_agg)) for j in range(0, len(train_agg[i]))]

# %%
train_agg_x1
# Out:
# [-8,
#  -38,
#  8,
#  26,
#  -14,
#  -3,
#  0,
#  -5,
#  3,
#  -6,
#  -21,
#  -3,
#  31,
#  91,
#  8,
#  11,
#  22,
#  2,
#  -4,
#  -5,
#  -31,
#  -13,
#  -15,
#  -15,
#  -14,
#  -18,
#  41,
#  24,
#  -49,
#  36,
#  9,
#  15,
#  -3,
#  0,
#  36,
#  -181,
#  -36,
#  1,
#  14,
#  3,
#  -34,
#  25,
#  14,
#  6,
#  -28,
#  -13,
#  -8,
#  0,
#  9,
#  8,
#  12,
#  1,
#  -3,
#  -31,
#  12,
#  13,
#  0,
#  -6,
#  -12,
#  -11,
#  -3,
#  -9,
#  31,
#  -34,
#  25,
#  -46,
#  273,
#  45,
#  41,
#  27,
#  38,
#  -180,
#  35,
#  76,
#  50,
#  -83,
#  -126,
#  -6,
#  4,
#  29,
#  41,
#  61,
#  31,
#  44,
#  -102,
#  1,
#  -13,
#  -9,
#  -18,
#  63,
#  55,
#  29,
#  -106,
#  12,
#  66,
#  21,
#  -41,
#  -51,
#  14,
#  57,
#  -17,
#  0,
#  4,
#  -28,
#  -27,
#  -22,
#  -17,
#  41,
#  41,
#  57,
#  84,
#  26,
#  22,
#  10,
#  -3,
#  -14,
#  -10,
#  -16,
#  -59,
#  -49,
#  150,
#  -1,
#  -11,
#  -9,
#  -18,
#  -8,
#  0,
#  -6,
#  4,
#  -22,
#  -12,
#  -35,
#  -21,
#  -29,
#  -15,
#  -36,
#  -31,
# ...

# %%
test_agg.shape

# %%
validation_agg.shape

# %%
train_agg.shape

# %%
def plot_samples(input_array, rows=1, cols=5, title=''):
    fig, ax = plt.subplots(figsize=(cols,rows))
    ax.axis('off')
    plt.title(title)

    for i in list(range(0, min(len(input_array),(rows*cols)) )):      
        a = fig.add_subplot(rows,cols,i+1)
        imgplot = plt.imshow(input_array[i,:784].reshape((28,28)), cmap='gray_r', interpolation='nearest')
        plt.xticks([])
        plt.yticks([])

# %%
plot_samples(cat_data, title='Sample arm drawings\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-0df75023aaf7> in <module>()
# ----> 1 plot_samples(cat_data, title='Sample arm drawings\n')
#
# <ipython-input-29-fceb145fbcfb> in plot_samples(input_array, rows, cols, title)
#       4     plt.title(title)
#       5
# ----> 6     for i in list(range(0, min(len(input_array),(rows*cols)) )):
#       7         a = fig.add_subplot(rows,cols,i+1)
#       8         imgplot = plt.imshow(input_array[i,:784].reshape((28,28)), cmap='gray_r', interpolation='nearest')
#
# TypeError: object of type 'NpzFile' has no len()
